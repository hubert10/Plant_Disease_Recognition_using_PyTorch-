# %%
import torch
import glob
import os
import cv2
import matplotlib.pyplot as plt
import random

from torchvision import transforms

# %%
train_image_path = os.path.join(
    '..', 
    'input', 
    'Train', 
    'Train',
    '*',
    '*.jpg'
)
all_image_paths = glob.glob(train_image_path, recursive=True)

# %%
print(all_image_paths[:5])
# Out:
# ['../input/Train/Train/Powdery/cafe25b4aeb0a8a1.jpg', '../input/Train/Train/Powdery/d6ce7e7e81854cc0.jpg', '../input/Train/Train/Powdery/f5c66368723bc942.jpg', '../input/Train/Train/Powdery/bae44a17ce0438bf.jpg', '../input/Train/Train/Powdery/f0f4d2c90c3d187b.jpg']

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(35),
    transforms.RandomAdjustSharpness(sharpness_factor=2, p=0.5),
])

# %%
plt.figure(figsize=(10, 7))
for i, image_path in enumerate(all_image_paths):
    if i == 9:
        break
    image_index = random.randint(0, len(all_image_paths))
    image = cv2.imread(all_image_paths[image_index])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    tranformed_image = train_transform(image)
    plt.subplot(3, 3, i+1)
    plt.imshow(tranformed_image)
    plt.axis('off')
plt.tight_layout()
plt.show()
